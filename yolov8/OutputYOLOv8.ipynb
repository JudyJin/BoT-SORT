# %%
# !pip install roboflow

# %%
# pip install ultralytics

# %%
from roboflow import Roboflow

# %%
# !unzip /content/150frames_30to60-20230424T183245Z-001.zip

# %%
# !unzip /content/reid_test-99-20230425T035826Z-001.zip

# %%
# !unzip /content/ezgif_150_1-20230426T184022Z-001.zip

# %%
# !mkdir test_frames

# %%
# !unzip /content/final_test_frame.zip -d /content/test_frames

# %%
# !mkdir test_files

# %%
# !unzip /content/ezgif-2-8c562ad804-jpg.zip -d /content/test_files

# %%
# This is Model of Face bounding box
# rf = Roboflow(api_key="KNgvDxqsjJ3COfFnPrYo")
# project = rf.workspace("deep-learning-computer-vision-model").project("yolo_fine")
# dataset = project.version(1).download("yolov8")
# model_face = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.88, to fix: `pip install ultralytics<=8.0.20`
# Downloading Dataset Version Zip in YOLO_Fine-1 to yolov8: 100% [2890416 / 2890416] bytes
# Extracting Dataset Version Zip to YOLO_Fine-1 in yolov8:: 100%|██████████| 312/312 [00:00<00:00, 7490.09it/s]

# %%
# This is Model of Body and Face bounding box
# rf = Roboflow(api_key="KNgvDxqsjJ3COfFnPrYo")
# project = rf.workspace("deep-learning-computer-vision-model").project("yolo_botsort")
# dataset = project.version(1).download("yolov8")

# model = project.version(1).model

# %%
# This is Model of Midterm Face bounding box

rf = Roboflow(api_key="KNgvDxqsjJ3COfFnPrYo")
project = rf.workspace("deep-learning-computer-vision-model").project("people-detection-rcmjk")
dataset = project.version(1).download("yolov8")

model_mid = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.88, to fix: `pip install ultralytics<=8.0.20`
# Downloading Dataset Version Zip in People-Detection-1 to yolov8: 100% [5031862 / 5031862] bytes
# Extracting Dataset Version Zip to People-Detection-1 in yolov8:: 100%|██████████| 230/230 [00:00<00:00, 7582.01it/s]

# %%
print(model_mid.predict("/content/test_frames/final_test_frame/0000.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 283, 'y': 133, 'width': 138, 'height': 105, 'confidence': 0.6002954244613647, 'class': '0', 'image_path': '/content/test_frames/final_test_frame/0000.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '1280', 'height': '720'}}

# %%
prd = model_mid.predict("/content/test_frames/final_test_frame/0000.jpg", confidence=40, overlap=30)
prd.plot()

# %%
# parts = []
# url_base = 'https://detect.roboflow.com/'
# endpoint = '[YOUR-MODEL]'
# access_token = '?access_token=[YOUR_TOKEN]'
# format = '&format=json'
# confidence = '&confidence=10'
# stroke='&stroke=5'
# parts.append(url_base)
# parts.append(endpoint)
# parts.append(access_token)
# parts.append(format)
# parts.append(confidence)
# parts.append(stroke)
# url = ''.join(parts)

# %%
import os

# %%
import json

# %%
# !mkdir test_print

# %%
# !rm *

# %%
# !mkdir final_test_json

# %%
# !mkdir final_test_json_face

# %%
# !mkdir mid_test_json

# %%
prediction = []
result = []
fine_res = []
final_res = []
face_res = []
mid_res = []
dir = '/content/test_frames/final_test_frame'
dir_name = "/content/mid_test_json"
# i = 0
for fn in sorted(os.listdir(dir)):
  # prediction = model.predict("/content/ezgif-frame-001.jpg")
  f = os.path.join(dir,fn)
  if os.path.isfile(f):
    # print(f)
    # break
    prediction_model = model_mid.predict(f)
    # file_path = os.path.join(dir_name, f"ezgif-frame-{i}.json")
    # print(prediction.json())
    prediction_model.json()
    # print(type(prediction_model))
    # print(prediction_model.json()['predictions'])
    # print(type(prediction_model.json()['predictions']))
    # break
    # prediction.save()
    for res in prediction_model.json()['predictions']:
      # result.append(res)
      # fine_res.append(res)
      # final_res.append(res)
      # face_res.append(res)
      mid_res.append(res)


    prediction.append(prediction_model)

# %%
print(mid_res[150])
print(type(mid_res[150]))
# Out:
# {'x': 243, 'y': 128, 'width': 126, 'height': 109, 'confidence': 0.8295086026191711, 'class': '0', 'image_path': '/content/test_frames/final_test_frame/0215.jpg', 'prediction_type': 'ObjectDetectionModel'}
# <class 'dict'>

# %%
# print(prediction[1])
# print(prediction[2])

# %%
# !mkdir json_files

# %%
# type(prediction[1])

# %%
# pred = list(prediction)
# type(pred[1])
# json_string = json.dumps(prediction)
# print(type(json_string))

# %%
# for i in range(len(pred)):
#   pred[i] = dict(pred[i])

# %%
# print(pred)

# %%
# dir_name = "/content/json_files/"
# # if not os.path.exists(dir_name):
# #     os.makedirs(dir_name)

# # for i, json_obj in enumerate(prediction):
# #   with open(f"ezgif-frame-{i}.json", "w") as outfile:
# #     json.dump(json_obj, outfile)
# pred_list = []

# for res in prediction.json()['predictions']:
#   pred_list.append(res)
#     # Save the JSON object to a file in the directory
#     # print(pred)

#     # file_path = os.path.join(dir_name, f"ezgif-frame-{i}.json")
#     # # json_str = json.dumps(json_obj)
#     # # print(json_str)
#     # print(json_obj['predictions'])
#     # print(type(json_obj['predictions']))
#     # break
#     # # break
#     # # json_dict = json_obj.to_dict()
#     # with open(file_path, "w") as outfile:
#     #   # print(outfile)
#     #   # break
#     #   # pred = json.dumps(prediction[i])
#     #   # # pred = prediction[i].json
#     #   # print(pred)
#     #   # break
      
#     #   # break
      
#     #   json.dump(json_obj, outfile)

# %%
# print(pred_list[1])
# print(type(pred_list[1]))

# %%
# !mkdir json_files

# %%
dir_name = "/content/mid_test_json"
# pre = 'ezgif-frame-'

for i, dictionary in enumerate(mid_res):
    # Save the JSON object to a file in the directory
    json_file_name = '{:04d}.json'.format(i)
    file_path = os.path.join(dir_name, json_file_name)
    with open(file_path, "w") as outfile:
        json.dump(dictionary, outfile)

# %%
# !zip -r /content/final_test_json.zip /content/

# %%
# import os 
# import json
# import shutil
# import pandas as pd

# %%
# frame_path = 'frames'
# annotation_path = 'annotations'
# output_path = 'dataset'
# def sanity_check(annot):
#     result = True
#     message = ''
#     ids = [False, False, False, False]
#     for item in annot['shapes']:
#         # print('item: ', item['label'], item['points'], item['shape_type'])
#         if item['label'] not in ['1', '2', '3', '4', '11', '22', '33', '44']:
#             result = False
#             message += 'invalid class id: {}\n'.format(item['label'])
#             break
#         class_id = int(item['label'])
        
#         if class_id in [1, 2, 3, 4]:
#             ids[class_id-1] = True
#             shape = item['shape_type']
#             if shape == 'rectangle':
#                 x_min, y_min = item['points'][0]
#                 x_max, y_max = item['points'][1]
#                 # assert(x_min < x_max), 'x_min: {}, x_max: {}'.format(x_min, x_max)
#                 # assert(y_min < y_max), 'y_min: {}, y_max: {}'.format(y_min, y_max)
#                 if x_min < x_max and y_min < y_max:
#                     pass
#                 else:
#                     result = False
#                     message += 'x_min: {}, x_max: {}, y_min: {}, y_max: {}\n'.format(x_min, x_max, y_min, y_max)
#                     break
#                     # print('x_min: {}, x_max: {}, y_min: {}, y_max: {}'.format(x_min, x_max, y_min, y_max))
#                 # print('x_min: ', x_min, 'y_min: ', y_min, 'x_max: ', x_max, 'y_max: ', y_max)
#             # elif shape == 'point':
#             #     gaze_x, gaze_y = item['points'][0]
#             #     anno_dicts[class_id-1]['gaze'] = [int(gaze_x), int(gaze_y)]
#                 # print('gaze_x: ', gaze_x, 'gaze_y: ', gaze_y)
#         else:
#             pass
#     for i in range(4):
#         if not ids[i]:
#             result = False
#             message += 'class {} not found\n'.format(i+1)
#     return result, message

# %%
# for dir in os.listdir(annotation_path):
#     if os.path.isdir(os.path.join(annotation_path, dir)):
#         print('video name: ', dir)
#         os.makedirs(os.path.join(output_path, 'images', dir), exist_ok=True)
#         os.makedirs(os.path.join(output_path, 'annotations', dir), exist_ok=True)
#         annos = [[], [], [], []]
#         print(annos)
#         for file in os.listdir(os.path.join(annotation_path, dir)):
#             if file.endswith('.json'):
#                 anno = json.load(open(os.path.join(annotation_path, dir, file)))
#                 frame_name = file.split('.')[0] + '.jpg'
#                 sanity_check_passed, sanity_message = sanity_check(anno)
#                 if not sanity_check_passed:
#                     print('sanity check failed for frame {}: {}'.format(dir+'/'+frame_name, sanity_message))
#                     continue

#                 shutil.copy(os.path.join(frame_path, dir, frame_name), os.path.join(output_path, 'images', dir, frame_name))
#                 print('frame name: ', frame_name)
#                 # print('keys: ', anno.keys()) # dict_keys(['version', 'flags', 'shapes', 'imagePath', 'imageData', 'imageHeight', 'imageWidth'])
#                 anno_dicts = [{
#                         'frame_name': frame_name,
#                         'bbox': None,
#                         'gaze': [-1, -1],
#                     } for i in range(4)]
#                 # print('anno_dicts: ', anno_dicts)
#                 for item in anno['shapes']:
#                     # print('item: ', item['label'], item['points'], item['shape_type'])
#                     class_id = int(item['label'])
#                     if class_id in [1, 2, 3, 4]:
#                         shape = item['shape_type']
#                         if shape == 'rectangle':
#                             x_min, y_min = item['points'][0]
#                             x_max, y_max = item['points'][1]
#                             # assert(x_min < x_max), 'x_min: {}, x_max: {}'.format(x_min, x_max)
#                             # assert(y_min < y_max), 'y_min: {}, y_max: {}'.format(y_min, y_max)
#                             if x_min < x_max and y_min < y_max:
#                                 anno_dicts[class_id-1]['bbox'] = [int(x_min), int(y_min), int(x_max), int(y_max)]
#                             else:
#                                 assert(x_min < x_max), 'x_min: {}, x_max: {}'.format(x_min, x_max)
#                                 assert(y_min < y_max), 'y_min: {}, y_max: {}'.format(y_min, y_max)
#                                 # print('x_min: {}, x_max: {}, y_min: {}, y_max: {}'.format(x_min, x_max, y_min, y_max))
#                             # print('x_min: ', x_min, 'y_min: ', y_min, 'x_max: ', x_max, 'y_max: ', y_max)
#                         elif shape == 'point':
#                             gaze_x, gaze_y = item['points'][0]
#                             anno_dicts[class_id-1]['gaze'] = [int(gaze_x), int(gaze_y)]
#                             # print('gaze_x: ', gaze_x, 'gaze_y: ', gaze_y)
#                     else:
#                         pass
#                 for i in range(4):
#                     if anno_dicts[i]['bbox'] is not None:
#                         result = []
#                         result.append(anno_dicts[i]['frame_name'])
#                         for j in range(4):
#                             result.append(str(anno_dicts[i]['bbox'][j]))
#                         for j in range(2):
#                             result.append(str(anno_dicts[i]['gaze'][j]))
#                         annos[i].append(','.join(result))
#             #             print(','.join(result))
#             #             print('anno_dicts ', i+1, anno_dicts[i])
#             #             print('annos ', i+1, annos[i])
#             # # foo
#             # for i in range(4):
#             #     print('annos ', i+1, annos[i])
#         for i in range(4):
#             # print('annos ', i+1, annos[i])
#             with open(os.path.join(output_path, 'annotations', dir, 's%2d.txt' % (i+1)), 'w') as f:
#                 for item in annos[i]:
#                     f.write(item + '\n')                
            
#     else:
#         print('here', dir)
#         continue

# %%
import json
import csv
import os

# %%
# !mkdir output_text_mid

# %%
# Path to the directory containing the JSON files
json_dir = "/content/mid_test_json"

# Path to the directory to store output text files
output_dir = "/content/output_text_mid"

# Dictionary to store the data for each class
class_data = {}

# Loop through each file in the directory
for filename in os.listdir(json_dir):
    # Make sure the file is a JSON file
    if filename.endswith(".json"):
        # Open the JSON file and load the data
        with open(os.path.join(json_dir, filename)) as json_file:
            data = json.load(json_file)
            # Extract the values from the JSON data
            image_path = data["image_path"]
            x = data["x"]
            y = data["y"]
            width = data["width"]
            height = data["height"]

            x1 = x - (width/2)
            x2 = x + (width/2)
            y1 = y - (height/2)
            y2 = y - (height/2)
            class_num = data["class"]

            if class_num not in class_data:
                class_data[class_num] = []
            class_data[class_num].append([image_path, x1, y1, x2, y2])

            # Loop through the data for each class and write it to the output text file
for class_num, data in class_data.items():
    # Create the output directory if it doesn't exist
    class_dir = os.path.join(output_dir, "class" + str(class_num))
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

        # Create the output text file for the class
    output_file = os.path.join(class_dir, "class" + str(class_num) + ".txt")
    # Write the values to the output text file
    with open(output_file, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["image_path", "x1", "y1", "x2", "y2"])
        for row in data:
            writer.writerow(row)

            # # Create the output directory if it doesn't exist
            # class_dir = os.path.join(output_dir, "class" + str(class_num))
            # if not os.path.exists(class_dir):
            #     os.makedirs(class_dir)
            

            # # Create the output text file for the class
            # output_file = os.path.join(class_dir, os.path.splitext(filename)[0] + ".txt")
            # # Write the values to the output text file
            # with open(output_file, "w", newline="") as f:
            #     writer = csv.writer(f)
            #     writer.writerow(["image_path", "x1", "y1", "x2", "y2"])
            #     writer.writerow([image_path, x1, y1, x2, y2])

# %%
# !zip -r /content/output_text_face_TXT.zip /content/output_text_face
# /content/output_text_final

# %%
# !zip -r /content/test_face_json.zip /content/final_test_json_face

# %%
# !zip -r /content/output_text_mid_TXT.zip /content/output_text_mid
# Out:
#   adding: content/output_text_mid/ (stored 0%)
#   adding: content/output_text_mid/class0/ (stored 0%)
#   adding: content/output_text_mid/class0/class0.txt (deflated 85%)

# %%
# !zip -r /content/mid_test_json.zip /content/mid_test_json
# Out:
#   adding: content/mid_test_json/ (stored 0%)
#   adding: content/mid_test_json/0196.json (deflated 24%)
#   adding: content/mid_test_json/0336.json (deflated 25%)
#   adding: content/mid_test_json/0887.json (deflated 25%)
#   adding: content/mid_test_json/1102.json (deflated 25%)
#   adding: content/mid_test_json/0649.json (deflated 25%)
#   adding: content/mid_test_json/0927.json (deflated 25%)
#   adding: content/mid_test_json/0398.json (deflated 25%)
#   adding: content/mid_test_json/0618.json (deflated 25%)
#   adding: content/mid_test_json/1110.json (deflated 25%)
#   adding: content/mid_test_json/0518.json (deflated 25%)
#   adding: content/mid_test_json/1275.json (deflated 25%)
#   adding: content/mid_test_json/0931.json (deflated 24%)
#   adding: content/mid_test_json/0541.json (deflated 25%)
#   adding: content/mid_test_json/0067.json (deflated 25%)
#   adding: content/mid_test_json/0739.json (deflated 25%)
#   adding: content/mid_test_json/0899.json (deflated 24%)
#   adding: content/mid_test_json/1006.json (deflated 25%)
#   adding: content/mid_test_json/0142.json (deflated 25%)
#   adding: content/mid_test_json/1062.json (deflated 24%)
#   adding: content/mid_test_json/0645.json (deflated 24%)
#   adding: content/mid_test_json/0534.json (deflated 25%)
#   adding: content/mid_test_json/0036.json (deflated 25%)
#   adding: content/mid_test_json/0343.json (deflated 25%)
#   adding: content/mid_test_json/0045.json (deflated 25%)
#   adding: content/mid_test_json/0676.json (deflated 25%)
#   adding: content/mid_test_json/0494.json (deflated 25%)
#   adding: content/mid_test_json/1112.json (deflated 25%)
#   adding: content/mid_test_json/0910.json (deflated 24%)
#   adding: content/mid_test_json/0297.json (deflated 25%)
#   adding: content/mid_test_json/1387.json (deflated 25%)
#   adding: content/mid_test_json/0167.json (deflated 25%)
#   adding: content/mid_test_json/0670.json (deflated 25%)
#   adding: content/mid_test_json/0377.json (deflated 25%)
#   adding: content/mid_test_json/1329.json (deflated 24%)
#   adding: content/mid_test_json/0568.json (deflated 25%)
#   adding: content/mid_test_json/0718.json (deflated 24%)
#   adding: content/mid_test_json/1373.json (deflated 25%)
#   adding: content/mid_test_json/0066.json (deflated 24%)
#   adding: content/mid_test_json/0314.json (deflated 25%)
#   adding: content/mid_test_json/1265.json (deflated 25%)
#   adding: content/mid_test_json/0129.json (deflated 24%)
#   adding: content/mid_test_json/1242.json (deflated 26%)
#   adding: content/mid_test_json/1281.json (deflated 25%)
#   adding: content/mid_test_json/0753.json (deflated 25%)
#   adding: content/mid_test_json/0955.json (deflated 24%)
#   adding: content/mid_test_json/1113.json (deflated 24%)
#   adding: content/mid_test_json/0521.json (deflated 24%)
#   adding: content/mid_test_json/0989.json (deflated 24%)
#   adding: content/mid_test_json/1414.json (deflated 24%)
#   adding: content/mid_test_json/0859.json (deflated 25%)
#   adding: content/mid_test_json/0058.json (deflated 25%)
#   adding: content/mid_test_json/0271.json (deflated 25%)
#   adding: content/mid_test_json/1074.json (deflated 24%)
#   adding: content/mid_test_json/1123.json (deflated 25%)
#   adding: content/mid_test_json/1090.json (deflated 25%)
#   adding: content/mid_test_json/0861.json (deflated 25%)
#   adding: content/mid_test_json/0361.json (deflated 25%)
#   adding: content/mid_test_json/1126.json (deflated 25%)
#   adding: content/mid_test_json/1143.json (deflated 25%)
#   adding: content/mid_test_json/0505.json (deflated 25%)
#   adding: content/mid_test_json/0883.json (deflated 25%)
#   adding: content/mid_test_json/1334.json (deflated 25%)
#   adding: content/mid_test_json/0041.json (deflated 25%)
#   adding: content/mid_test_json/0544.json (deflated 25%)
#   adding: content/mid_test_json/0602.json (deflated 25%)
#   adding: content/mid_test_json/0460.json (deflated 25%)
#   adding: content/mid_test_json/0501.json (deflated 24%)
#   adding: content/mid_test_json/0747.json (deflated 25%)
#   adding: content/mid_test_json/1140.json (deflated 24%)
#   adding: content/mid_test_json/0875.json (deflated 24%)
#   adding: content/mid_test_json/1103.json (deflated 24%)
#   adding: content/mid_test_json/0629.json (deflated 25%)
#   adding: content/mid_test_json/0672.json (deflated 24%)
#   adding: content/mid_test_json/1150.json (deflated 24%)
#   adding: content/mid_test_json/0173.json (deflated 25%)
#   adding: content/mid_test_json/0236.json (deflated 25%)
#   adding: content/mid_test_json/0274.json (deflated 24%)
#   adding: content/mid_test_json/0917.json (deflated 25%)
#   adding: content/mid_test_json/0565.json (deflated 25%)
#   adding: content/mid_test_json/1381.json (deflated 25%)
#   adding: content/mid_test_json/1284.json (deflated 25%)
#   adding: content/mid_test_json/0642.json (deflated 24%)
#   adding: content/mid_test_json/0716.json (deflated 24%)
#   adding: content/mid_test_json/0483.json (deflated 24%)
#   adding: content/mid_test_json/0881.json (deflated 24%)
#   adding: content/mid_test_json/0290.json (deflated 25%)
#   adding: content/mid_test_json/0850.json (deflated 24%)
#   adding: content/mid_test_json/1215.json (deflated 25%)
#   adding: content/mid_test_json/0530.json (deflated 25%)
#   adding: content/mid_test_json/0808.json (deflated 25%)
#   adding: content/mid_test_json/0892.json (deflated 25%)
#   adding: content/mid_test_json/1309.json (deflated 24%)
#   adding: content/mid_test_json/0648.json (deflated 25%)
#   adding: content/mid_test_json/0821.json (deflated 25%)
#   adding: content/mid_test_json/1026.json (deflated 25%)
#   adding: content/mid_test_json/0636.json (deflated 24%)
#   adding: content/mid_test_json/0916.json (deflated 24%)
#   adding: content/mid_test_json/1378.json (deflated 25%)
#   adding: content/mid_test_json/0145.json (deflated 25%)
#   adding: content/mid_test_json/1355.json (deflated 24%)
#   adding: content/mid_test_json/0283.json (deflated 25%)
#   adding: content/mid_test_json/0906.json (deflated 24%)
#   adding: content/mid_test_json/0600.json (deflated 24%)
#   adding: content/mid_test_json/0612.json (deflated 24%)
#   adding: content/mid_test_json/0696.json (deflated 25%)
#   adding: content/mid_test_json/1173.json (deflated 24%)
#   adding: content/mid_test_json/0169.json (deflated 25%)
#   adding: content/mid_test_json/0698.json (deflated 24%)
#   adding: content/mid_test_json/0904.json (deflated 24%)
#   adding: content/mid_test_json/0556.json (deflated 24%)
#   adding: content/mid_test_json/0401.json (deflated 25%)
#   adding: content/mid_test_json/1239.json (deflated 26%)
#   adding: content/mid_test_json/0263.json (deflated 24%)
#   adding: content/mid_test_json/0387.json (deflated 25%)
#   adding: content/mid_test_json/0760.json (deflated 24%)
#   adding: content/mid_test_json/0410.json (deflated 25%)
#   adding: content/mid_test_json/0999.json (deflated 25%)
#   adding: content/mid_test_json/0898.json (deflated 25%)
#   adding: content/mid_test_json/1217.json (deflated 25%)
#   adding: content/mid_test_json/0005.json (deflated 24%)
#   adding: content/mid_test_json/0208.json (deflated 25%)
#   adding: content/mid_test_json/0451.json (deflated 25%)
#   adding: content/mid_test_json/0215.json (deflated 25%)
#   adding: content/mid_test_json/1346.json (deflated 25%)
#   adding: content/mid_test_json/0763.json (deflated 25%)
#   adding: content/mid_test_json/0499.json (deflated 25%)
#   adding: content/mid_test_json/1385.json (deflated 25%)
#   adding: content/mid_test_json/0082.json (deflated 25%)
#   adding: content/mid_test_json/0741.json (deflated 25%)
#   adding: content/mid_test_json/0391.json (deflated 24%)
#   adding: content/mid_test_json/0466.json (deflated 25%)
#   adding: content/mid_test_json/1410.json (deflated 24%)
#   adding: content/mid_test_json/1395.json (deflated 25%)
#   adding: content/mid_test_json/0112.json (deflated 25%)
#   adding: content/mid_test_json/0315.json (deflated 25%)
#   adding: content/mid_test_json/1232.json (deflated 24%)
#   adding: content/mid_test_json/0832.json (deflated 25%)
#   adding: content/mid_test_json/0110.json (deflated 25%)
#   adding: content/mid_test_json/0306.json (deflated 25%)
#   adding: content/mid_test_json/0118.json (deflated 25%)
#   adding: content/mid_test_json/1191.json (deflated 25%)
#   adding: content/mid_test_json/1420.json (deflated 25%)
#   adding: content/mid_test_json/0140.json (deflated 25%)
#   adding: content/mid_test_json/0920.json (deflated 25%)
#   adding: content/mid_test_json/0386.json (deflated 25%)
#   adding: content/mid_test_json/0115.json (deflated 25%)
#   adding: content/mid_test_json/1268.json (deflated 25%)
#   adding: content/mid_test_json/0153.json (deflated 25%)
#   adding: content/mid_test_json/0826.json (deflated 25%)
#   adding: content/mid_test_json/1201.json (deflated 25%)
#   adding: content/mid_test_json/0886.json (deflated 25%)
#   adding: content/mid_test_json/0949.json (deflated 24%)
#   adding: content/mid_test_json/0409.json (deflated 25%)
#   adding: content/mid_test_json/0930.json (deflated 25%)
#   adding: content/mid_test_json/0265.json (deflated 25%)
#   adding: content/mid_test_json/0298.json (deflated 24%)
#   adding: content/mid_test_json/1277.json (deflated 24%)
#   adding: content/mid_test_json/0786.json (deflated 25%)
#   adding: content/mid_test_json/1136.json (deflated 25%)
#   adding: content/mid_test_json/1408.json (deflated 25%)
#   adding: content/mid_test_json/0796.json (deflated 25%)
#   adding: content/mid_test_json/1257.json (deflated 25%)
#   adding: content/mid_test_json/1406.json (deflated 24%)
#   adding: content/mid_test_json/1253.json (deflated 25%)
#   adding: content/mid_test_json/0149.json (deflated 24%)
#   adding: content/mid_test_json/0767.json (deflated 25%)
#   adding: content/mid_test_json/0084.json (deflated 25%)
#   adding: content/mid_test_json/1071.json (deflated 25%)
#   adding: content/mid_test_json/0302.json (deflated 25%)
#   adding: content/mid_test_json/0588.json (deflated 25%)
#   adding: content/mid_test_json/1357.json (deflated 25%)
#   adding: content/mid_test_json/0599.json (deflated 25%)
#   adding: content/mid_test_json/0213.json (deflated 25%)
#   adding: content/mid_test_json/1116.json (deflated 24%)
#   adding: content/mid_test_json/0217.json (deflated 25%)
#   adding: content/mid_test_json/0993.json (deflated 24%)
#   adding: content/mid_test_json/0557.json (deflated 25%)
#   adding: content/mid_test_json/1055.json (deflated 25%)
#   adding: content/mid_test_json/1023.json (deflated 24%)
#   adding: content/mid_test_json/1332.json (deflated 25%)
#   adding: content/mid_test_json/0925.json (deflated 25%)
#   adding: content/mid_test_json/0407.json (deflated 25%)
#   adding: content/mid_test_json/1354.json (deflated 25%)
#   adding: content/mid_test_json/0657.json (deflated 25%)
#   adding: content/mid_test_json/1059.json (deflated 24%)
#   adding: content/mid_test_json/0562.json (deflated 25%)
#   adding: content/mid_test_json/0445.json (deflated 25%)
#   adding: content/mid_test_json/1301.json (deflated 25%)
#   adding: content/mid_test_json/0913.json (deflated 25%)
#   adding: content/mid_test_json/0604.json (deflated 25%)
#   adding: content/mid_test_json/0625.json (deflated 25%)
#   adding: content/mid_test_json/0366.json (deflated 25%)
#   adding: content/mid_test_json/0372.json (deflated 25%)
#   adding: content/mid_test_json/0660.json (deflated 25%)
#   adding: content/mid_test_json/0378.json (deflated 25%)
#   adding: content/mid_test_json/0547.json (deflated 25%)
#   adding: content/mid_test_json/0178.json (deflated 25%)
#   adding: content/mid_test_json/1067.json (deflated 25%)
#   adding: content/mid_test_json/0564.json (deflated 25%)
#   adding: content/mid_test_json/0182.json (deflated 25%)
#   adding: content/mid_test_json/1091.json (deflated 25%)
#   adding: content/mid_test_json/0679.json (deflated 25%)
#   adding: content/mid_test_json/0137.json (deflated 25%)
#   adding: content/mid_test_json/0395.json (deflated 25%)
#   adding: content/mid_test_json/1013.json (deflated 25%)
#   adding: content/mid_test_json/0736.json (deflated 24%)
#   adding: content/mid_test_json/0929.json (deflated 24%)
#   adding: content/mid_test_json/0257.json (deflated 25%)
#   adding: content/mid_test_json/0259.json (deflated 25%)
#   adding: content/mid_test_json/1046.json (deflated 25%)
#   adding: content/mid_test_json/0022.json (deflated 24%)
#   adding: content/mid_test_json/0751.json (deflated 24%)
#   adding: content/mid_test_json/0732.json (deflated 25%)
#   adding: content/mid_test_json/0355.json (deflated 25%)
#   adding: content/mid_test_json/0394.json (deflated 25%)
#   adding: content/mid_test_json/0804.json (deflated 26%)
#   adding: content/mid_test_json/0710.json (deflated 25%)
#   adding: content/mid_test_json/0392.json (deflated 25%)
#   adding: content/mid_test_json/0010.json (deflated 25%)
#   adding: content/mid_test_json/0412.json (deflated 24%)
#   adding: content/mid_test_json/0203.json (deflated 25%)
#   adding: content/mid_test_json/0125.json (deflated 25%)
#   adding: content/mid_test_json/0300.json (deflated 24%)
#   adding: content/mid_test_json/0131.json (deflated 25%)
#   adding: content/mid_test_json/0350.json (deflated 25%)
#   adding: content/mid_test_json/1040.json (deflated 24%)
#   adding: content/mid_test_json/0258.json (deflated 25%)
#   adding: content/mid_test_json/0782.json (deflated 24%)
#   adding: content/mid_test_json/0758.json (deflated 25%)
#   adding: content/mid_test_json/0901.json (deflated 25%)
#   adding: content/mid_test_json/0791.json (deflated 25%)
#   adding: content/mid_test_json/1086.json (deflated 25%)
#   adding: content/mid_test_json/1060.json (deflated 26%)
#   adding: content/mid_test_json/0699.json (deflated 25%)
#   adding: content/mid_test_json/0370.json (deflated 25%)
#   adding: content/mid_test_json/0426.json (deflated 24%)
#   adding: content/mid_test_json/0223.json (deflated 25%)
#   adding: content/mid_test_json/1160.json (deflated 24%)
#   adding: content/mid_test_json/0307.json (deflated 25%)
#   adding: content/mid_test_json/0359.json (deflated 25%)
#   adding: content/mid_test_json/0730.json (deflated 25%)
#   adding: content/mid_test_json/0312.json (deflated 25%)
#   adding: content/mid_test_json/0566.json (deflated 25%)
#   adding: content/mid_test_json/0293.json (deflated 25%)
#   adding: content/mid_test_json/0289.json (deflated 24%)
#   adding: content/mid_test_json/0801.json (deflated 25%)
#   adding: content/mid_test_json/0721.json (deflated 24%)
#   adding: content/mid_test_json/1278.json (deflated 24%)
#   adding: content/mid_test_json/0480.json (deflated 25%)
#   adding: content/mid_test_json/0200.json (deflated 25%)
#   adding: content/mid_test_json/0830.json (deflated 25%)
#   adding: content/mid_test_json/1223.json (deflated 25%)
#   adding: content/mid_test_json/1302.json (deflated 24%)
#   adding: content/mid_test_json/1121.json (deflated 24%)
#   adding: content/mid_test_json/1149.json (deflated 25%)
#   adding: content/mid_test_json/0974.json (deflated 25%)
#   adding: content/mid_test_json/0984.json (deflated 25%)
#   adding: content/mid_test_json/0296.json (deflated 24%)
#   adding: content/mid_test_json/0243.json (deflated 25%)
#   adding: content/mid_test_json/0895.json (deflated 24%)
#   adding: content/mid_test_json/0492.json (deflated 24%)
#   adding: content/mid_test_json/1083.json (deflated 25%)
#   adding: content/mid_test_json/1352.json (deflated 25%)
#   adding: content/mid_test_json/0444.json (deflated 25%)
#   adding: content/mid_test_json/1147.json (deflated 25%)
#   adding: content/mid_test_json/0727.json (deflated 24%)
#   adding: content/mid_test_json/0346.json (deflated 24%)
#   adding: content/mid_test_json/0072.json (deflated 24%)
#   adding: content/mid_test_json/1350.json (deflated 24%)
#   adding: content/mid_test_json/0719.json (deflated 25%)
#   adding: content/mid_test_json/0603.json (deflated 25%)
#   adding: content/mid_test_json/1027.json (deflated 24%)
#   adding: content/mid_test_json/0172.json (deflated 25%)
#   adding: content/mid_test_json/1411.json (deflated 24%)
#   adding: content/mid_test_json/0607.json (deflated 24%)
#   adding: content/mid_test_json/0614.json (deflated 25%)
#   adding: content/mid_test_json/0150.json (deflated 25%)
#   adding: content/mid_test_json/0653.json (deflated 24%)
#   adding: content/mid_test_json/1401.json (deflated 25%)
#   adding: content/mid_test_json/0100.json (deflated 25%)
#   adding: content/mid_test_json/0937.json (deflated 24%)
#   adding: content/mid_test_json/1372.json (deflated 25%)
#   adding: content/mid_test_json/0287.json (deflated 25%)
#   adding: content/mid_test_json/0224.json (deflated 25%)
#   adding: content/mid_test_json/1267.json (deflated 25%)
#   adding: content/mid_test_json/1251.json (deflated 25%)
#   adding: content/mid_test_json/0255.json (deflated 25%)
#   adding: content/mid_test_json/0650.json (deflated 24%)
#   adding: content/mid_test_json/1163.json (deflated 24%)
#   adding: content/mid_test_json/1349.json (deflated 25%)
#   adding: content/mid_test_json/0856.json (deflated 25%)
#   adding: content/mid_test_json/1005.json (deflated 24%)
#   adding: content/mid_test_json/0908.json (deflated 24%)
#   adding: content/mid_test_json/1247.json (deflated 25%)
#   adding: content/mid_test_json/0049.json (deflated 25%)
#   adding: content/mid_test_json/0234.json (deflated 25%)
#   adding: content/mid_test_json/0093.json (deflated 25%)
#   adding: content/mid_test_json/1236.json (deflated 25%)
#   adding: content/mid_test_json/1017.json (deflated 24%)
#   adding: content/mid_test_json/0380.json (deflated 25%)
#   adding: content/mid_test_json/0238.json (deflated 26%)
#   adding: content/mid_test_json/0044.json (deflated 24%)
#   adding: content/mid_test_json/0341.json (deflated 26%)
#   adding: content/mid_test_json/0440.json (deflated 25%)
#   adding: content/mid_test_json/1295.json (deflated 25%)
#   adding: content/mid_test_json/0429.json (deflated 25%)
#   adding: content/mid_test_json/1286.json (deflated 24%)
#   adding: content/mid_test_json/0997.json (deflated 25%)
#   adding: content/mid_test_json/0902.json (deflated 25%)
#   adding: content/mid_test_json/1078.json (deflated 25%)
#   adding: content/mid_test_json/0427.json (deflated 25%)
#   adding: content/mid_test_json/0640.json (deflated 24%)
#   adding: content/mid_test_json/0586.json (deflated 25%)
#   adding: content/mid_test_json/0249.json (deflated 25%)
#   adding: content/mid_test_json/0284.json (deflated 24%)
#   adding: content/mid_test_json/0654.json (deflated 25%)
#   adding: content/mid_test_json/0870.json (deflated 25%)
#   adding: content/mid_test_json/0572.json (deflated 24%)
#   adding: content/mid_test_json/1383.json (deflated 25%)
#   adding: content/mid_test_json/1384.json (deflated 25%)
#   adding: content/mid_test_json/0032.json (deflated 25%)
#   adding: content/mid_test_json/0810.json (deflated 25%)
#   adding: content/mid_test_json/1345.json (deflated 24%)
#   adding: content/mid_test_json/0839.json (deflated 25%)
#   adding: content/mid_test_json/1157.json (deflated 24%)
#   adding: content/mid_test_json/0790.json (deflated 24%)
#   adding: content/mid_test_json/0454.json (deflated 24%)
#   adding: content/mid_test_json/0001.json (deflated 25%)
#   adding: content/mid_test_json/1213.json (deflated 25%)
#   adding: content/mid_test_json/1359.json (deflated 24%)
#   adding: content/mid_test_json/0138.json (deflated 25%)
#   adding: content/mid_test_json/0465.json (deflated 25%)
#   adding: content/mid_test_json/0555.json (deflated 25%)
#   adding: content/mid_test_json/0785.json (deflated 25%)
#   adding: content/mid_test_json/0028.json (deflated 24%)
#   adding: content/mid_test_json/1106.json (deflated 24%)
#   adding: content/mid_test_json/1187.json (deflated 24%)
#   adding: content/mid_test_json/1146.json (deflated 24%)
#   adding: content/mid_test_json/0344.json (deflated 24%)
#   adding: content/mid_test_json/0088.json (deflated 25%)
#   adding: content/mid_test_json/1188.json (deflated 24%)
#   adding: content/mid_test_json/0766.json (deflated 26%)
#   adding: content/mid_test_json/0558.json (deflated 25%)
#   adding: content/mid_test_json/0661.json (deflated 25%)
#   adding: content/mid_test_json/0023.json (deflated 25%)
#   adding: content/mid_test_json/0349.json (deflated 25%)
#   adding: content/mid_test_json/1022.json (deflated 25%)
#   adding: content/mid_test_json/0862.json (deflated 24%)
#   adding: content/mid_test_json/0511.json (deflated 25%)
#   adding: content/mid_test_json/1202.json (deflated 25%)
#   adding: content/mid_test_json/1167.json (deflated 25%)
#   adding: content/mid_test_json/1024.json (deflated 24%)
#   adding: content/mid_test_json/0237.json (deflated 25%)
#   adding: content/mid_test_json/1292.json (deflated 24%)
#   adding: content/mid_test_json/0382.json (deflated 25%)
#   adding: content/mid_test_json/0450.json (deflated 25%)
#   adding: content/mid_test_json/0619.json (deflated 24%)
#   adding: content/mid_test_json/1198.json (deflated 25%)
#   adding: content/mid_test_json/0507.json (deflated 25%)
#   adding: content/mid_test_json/0694.json (deflated 25%)
#   adding: content/mid_test_json/1064.json (deflated 25%)
#   adding: content/mid_test_json/0219.json (deflated 25%)
#   adding: content/mid_test_json/0235.json (deflated 24%)
#   adding: content/mid_test_json/1158.json (deflated 25%)
#   adding: content/mid_test_json/0157.json (deflated 24%)
#   adding: content/mid_test_json/0464.json (deflated 24%)
#   adding: content/mid_test_json/0951.json (deflated 24%)
#   adding: content/mid_test_json/0539.json (deflated 25%)
#   adding: content/mid_test_json/0677.json (deflated 25%)
#   adding: content/mid_test_json/0430.json (deflated 24%)
#   adding: content/mid_test_json/1418.json (deflated 24%)
#   adding: content/mid_test_json/0744.json (deflated 24%)
#   adding: content/mid_test_json/0977.json (deflated 24%)
#   adding: content/mid_test_json/0972.json (deflated 24%)
#   adding: content/mid_test_json/0166.json (deflated 25%)
#   adding: content/mid_test_json/0560.json (deflated 24%)
#   adding: content/mid_test_json/0857.json (deflated 25%)
#   adding: content/mid_test_json/0787.json (deflated 25%)
#   adding: content/mid_test_json/0327.json (deflated 25%)
#   adding: content/mid_test_json/0089.json (deflated 24%)
#   adding: content/mid_test_json/0116.json (deflated 24%)
#   adding: content/mid_test_json/0496.json (deflated 24%)
#   adding: content/mid_test_json/0854.json (deflated 25%)
#   adding: content/mid_test_json/1207.json (deflated 25%)
#   adding: content/mid_test_json/0864.json (deflated 25%)
#   adding: content/mid_test_json/0991.json (deflated 25%)
#   adding: content/mid_test_json/1057.json (deflated 24%)
#   adding: content/mid_test_json/0722.json (deflated 25%)
#   adding: content/mid_test_json/1154.json (deflated 24%)
#   adding: content/mid_test_json/0324.json (deflated 25%)
#   adding: content/mid_test_json/1369.json (deflated 24%)
#   adding: content/mid_test_json/0876.json (deflated 25%)
#   adding: content/mid_test_json/0841.json (deflated 25%)
#   adding: content/mid_test_json/0836.json (deflated 25%)
#   adding: content/mid_test_json/1181.json (deflated 25%)
#   adding: content/mid_test_json/0909.json (deflated 24%)
#   adding: content/mid_test_json/1186.json (deflated 25%)
#   adding: content/mid_test_json/1131.json (deflated 25%)
#   adding: content/mid_test_json/0712.json (deflated 25%)
#   adding: content/mid_test_json/0415.json (deflated 25%)
#   adding: content/mid_test_json/0780.json (deflated 24%)
#   adding: content/mid_test_json/0813.json (deflated 25%)
#   adding: content/mid_test_json/0042.json (deflated 25%)
#   adding: content/mid_test_json/0891.json (deflated 25%)
#   adding: content/mid_test_json/1341.json (deflated 24%)
#   adding: content/mid_test_json/1366.json (deflated 25%)
#   adding: content/mid_test_json/0241.json (deflated 25%)
#   adding: content/mid_test_json/1289.json (deflated 25%)
#   adding: content/mid_test_json/1240.json (deflated 25%)
#   adding: content/mid_test_json/1182.json (deflated 25%)
#   adding: content/mid_test_json/0477.json (deflated 25%)
#   adding: content/mid_test_json/0623.json (deflated 25%)
#   adding: content/mid_test_json/1145.json (deflated 25%)
#   adding: content/mid_test_json/0400.json (deflated 25%)
#   adding: content/mid_test_json/0610.json (deflated 25%)
#   adding: content/mid_test_json/0461.json (deflated 25%)
#   adding: content/mid_test_json/0845.json (deflated 25%)
#   adding: content/mid_test_json/0890.json (deflated 24%)
#   adding: content/mid_test_json/0576.json (deflated 25%)
#   adding: content/mid_test_json/1169.json (deflated 24%)
#   adding: content/mid_test_json/0522.json (deflated 25%)
#   adding: content/mid_test_json/0769.json (deflated 25%)
#   adding: content/mid_test_json/1180.json (deflated 25%)
#   adding: content/mid_test_json/0233.json (deflated 25%)
#   adding: content/mid_test_json/0333.json (deflated 25%)
#   adding: content/mid_test_json/1252.json (deflated 24%)
#   adding: content/mid_test_json/0244.json (deflated 25%)
#   adding: content/mid_test_json/0457.json (deflated 24%)
#   adding: content/mid_test_json/1000.json (deflated 24%)
#   adding: content/mid_test_json/0068.json (deflated 25%)
#   adding: content/mid_test_json/1417.json (deflated 25%)
#   adding: content/mid_test_json/0934.json (deflated 25%)
#   adding: content/mid_test_json/1025.json (deflated 25%)
#   adding: content/mid_test_json/0384.json (deflated 25%)
#   adding: content/mid_test_json/0515.json (deflated 24%)
#   adding: content/mid_test_json/1299.json (deflated 24%)
#   adding: content/mid_test_json/1368.json (deflated 24%)
#   adding: content/mid_test_json/0548.json (deflated 25%)
#   adding: content/mid_test_json/0905.json (deflated 25%)
#   adding: content/mid_test_json/0798.json (deflated 25%)
#   adding: content/mid_test_json/0136.json (deflated 25%)
#   adding: content/mid_test_json/1048.json (deflated 25%)
#   adding: content/mid_test_json/0811.json (deflated 25%)
#   adding: content/mid_test_json/1076.json (deflated 25%)
#   adding: content/mid_test_json/0194.json (deflated 25%)
#   adding: content/mid_test_json/1391.json (deflated 25%)
#   adding: content/mid_test_json/0317.json (deflated 26%)
#   adding: content/mid_test_json/0549.json (deflated 24%)
#   adding: content/mid_test_json/1314.json (deflated 24%)
#   adding: content/mid_test_json/0745.json (deflated 25%)
#   adding: content/mid_test_json/0775.json (deflated 25%)
#   adding: content/mid_test_json/0981.json (deflated 25%)
#   adding: content/mid_test_json/0008.json (deflated 25%)
#   adding: content/mid_test_json/1030.json (deflated 24%)
#   adding: content/mid_test_json/0589.json (deflated 25%)
#   adding: content/mid_test_json/0709.json (deflated 25%)
#   adding: content/mid_test_json/1098.json (deflated 24%)
#   adding: content/mid_test_json/1144.json (deflated 24%)
#   adding: content/mid_test_json/0754.json (deflated 25%)
#   adding: content/mid_test_json/0016.json (deflated 25%)
#   adding: content/mid_test_json/0080.json (deflated 25%)
#   adding: content/mid_test_json/0559.json (deflated 24%)
#   adding: content/mid_test_json/0761.json (deflated 24%)
#   adding: content/mid_test_json/0944.json (deflated 24%)
#   adding: content/mid_test_json/0853.json (deflated 24%)
#   adding: content/mid_test_json/0802.json (deflated 25%)
#   adding: content/mid_test_json/0062.json (deflated 24%)
#   adding: content/mid_test_json/1419.json (deflated 24%)
#   adding: content/mid_test_json/1164.json (deflated 24%)
#   adding: content/mid_test_json/1226.json (deflated 25%)
#   adding: content/mid_test_json/0622.json (deflated 25%)
#   adding: content/mid_test_json/0552.json (deflated 24%)
#   adding: content/mid_test_json/1132.json (deflated 24%)
#   adding: content/mid_test_json/1214.json (deflated 24%)
#   adding: content/mid_test_json/0819.json (deflated 25%)
#   adding: content/mid_test_json/0578.json (deflated 25%)
#   adding: content/mid_test_json/0554.json (deflated 25%)
#   adding: content/mid_test_json/1008.json (deflated 25%)
#   adding: content/mid_test_json/0742.json (deflated 25%)
#   adding: content/mid_test_json/0354.json (deflated 25%)
#   adding: content/mid_test_json/0682.json (deflated 24%)
#   adding: content/mid_test_json/0943.json (deflated 24%)
#   adding: content/mid_test_json/0373.json (deflated 25%)
#   adding: content/mid_test_json/0123.json (deflated 25%)
#   adding: content/mid_test_json/1050.json (deflated 25%)
#   adding: content/mid_test_json/0456.json (deflated 24%)
#   adding: content/mid_test_json/0455.json (deflated 25%)
#   adding: content/mid_test_json/0668.json (deflated 24%)
#   adding: content/mid_test_json/1196.json (deflated 24%)
#   adding: content/mid_test_json/0260.json (deflated 25%)
#   adding: content/mid_test_json/0226.json (deflated 25%)
#   adding: content/mid_test_json/0253.json (deflated 25%)
#   adding: content/mid_test_json/0364.json (deflated 25%)
#   adding: content/mid_test_json/0655.json (deflated 25%)
#   adding: content/mid_test_json/0703.json (deflated 25%)
#   adding: content/mid_test_json/0728.json (deflated 25%)
#   adding: content/mid_test_json/0230.json (deflated 25%)
#   adding: content/mid_test_json/0843.json (deflated 25%)
#   adding: content/mid_test_json/0294.json (deflated 25%)
#   adding: content/mid_test_json/0952.json (deflated 25%)
#   adding: content/mid_test_json/0436.json (deflated 25%)
#   adding: content/mid_test_json/0051.json (deflated 25%)
#   adding: content/mid_test_json/1313.json (deflated 25%)
#   adding: content/mid_test_json/0198.json (deflated 25%)
#   adding: content/mid_test_json/0918.json (deflated 24%)
#   adding: content/mid_test_json/0106.json (deflated 25%)
#   adding: content/mid_test_json/0590.json (deflated 25%)
#   adding: content/mid_test_json/0303.json (deflated 25%)
#   adding: content/mid_test_json/0152.json (deflated 25%)
#   adding: content/mid_test_json/0405.json (deflated 25%)
#   adding: content/mid_test_json/0127.json (deflated 25%)
#   adding: content/mid_test_json/0218.json (deflated 25%)
#   adding: content/mid_test_json/1203.json (deflated 25%)
#   adding: content/mid_test_json/0692.json (deflated 25%)
#   adding: content/mid_test_json/1258.json (deflated 24%)
#   adding: content/mid_test_json/1310.json (deflated 25%)
#   adding: content/mid_test_json/0256.json (deflated 25%)
#   adding: content/mid_test_json/0411.json (deflated 25%)
#   adding: content/mid_test_json/0278.json (deflated 25%)
#   adding: content/mid_test_json/0097.json (deflated 25%)
#   adding: content/mid_test_json/1297.json (deflated 24%)
#   adding: content/mid_test_json/0070.json (deflated 25%)
#   adding: content/mid_test_json/1061.json (deflated 25%)
#   adding: content/mid_test_json/1155.json (deflated 24%)
#   adding: content/mid_test_json/0519.json (deflated 25%)
#   adding: content/mid_test_json/1148.json (deflated 24%)
#   adding: content/mid_test_json/0686.json (deflated 25%)
#   adding: content/mid_test_json/0254.json (deflated 25%)
#   adding: content/mid_test_json/0542.json (deflated 25%)
#   adding: content/mid_test_json/0422.json (deflated 24%)
#   adding: content/mid_test_json/0165.json (deflated 25%)
#   adding: content/mid_test_json/1316.json (deflated 25%)
#   adding: content/mid_test_json/0680.json (deflated 25%)
#   adding: content/mid_test_json/0047.json (deflated 25%)
#   adding: content/mid_test_json/0713.json (deflated 24%)
#   adding: content/mid_test_json/1038.json (deflated 25%)
#   adding: content/mid_test_json/0526.json (deflated 25%)
#   adding: content/mid_test_json/0633.json (deflated 24%)
#   adding: content/mid_test_json/0658.json (deflated 25%)
#   adding: content/mid_test_json/0529.json (deflated 25%)
#   adding: content/mid_test_json/1011.json (deflated 25%)
#   adding: content/mid_test_json/1371.json (deflated 25%)
#   adding: content/mid_test_json/1256.json (deflated 25%)
#   adding: content/mid_test_json/1175.json (deflated 26%)
#   adding: content/mid_test_json/0095.json (deflated 24%)
#   adding: content/mid_test_json/0064.json (deflated 25%)
#   adding: content/mid_test_json/0749.json (deflated 25%)
#   adding: content/mid_test_json/0646.json (deflated 24%)
#   adding: content/mid_test_json/1115.json (deflated 25%)
#   adding: content/mid_test_json/0053.json (deflated 25%)
#   adding: content/mid_test_json/0013.json (deflated 24%)
#   adding: content/mid_test_json/1237.json (deflated 25%)
#   adding: content/mid_test_json/0286.json (deflated 25%)
#   adding: content/mid_test_json/0193.json (deflated 25%)
#   adding: content/mid_test_json/0006.json (deflated 25%)
#   adding: content/mid_test_json/0442.json (deflated 25%)
#   adding: content/mid_test_json/0982.json (deflated 25%)
#   adding: content/mid_test_json/0868.json (deflated 25%)
#   adding: content/mid_test_json/0383.json (deflated 25%)
#   adding: content/mid_test_json/1210.json (deflated 25%)
#   adding: content/mid_test_json/0509.json (deflated 24%)
#   adding: content/mid_test_json/1168.json (deflated 24%)
#   adding: content/mid_test_json/1358.json (deflated 25%)
#   adding: content/mid_test_json/1219.json (deflated 25%)
#   adding: content/mid_test_json/0171.json (deflated 25%)
#   adding: content/mid_test_json/0441.json (deflated 25%)
#   adding: content/mid_test_json/0776.json (deflated 25%)
#   adding: content/mid_test_json/1189.json (deflated 25%)
#   adding: content/mid_test_json/1230.json (deflated 24%)
#   adding: content/mid_test_json/0956.json (deflated 25%)
#   adding: content/mid_test_json/0577.json (deflated 24%)
#   adding: content/mid_test_json/1049.json (deflated 24%)
#   adding: content/mid_test_json/0404.json (deflated 25%)
#   adding: content/mid_test_json/0948.json (deflated 24%)
#   adding: content/mid_test_json/0159.json (deflated 25%)
#   adding: content/mid_test_json/0923.json (deflated 25%)
#   adding: content/mid_test_json/0979.json (deflated 25%)
#   adding: content/mid_test_json/0988.json (deflated 25%)
#   adding: content/mid_test_json/0275.json (deflated 25%)
#   adding: content/mid_test_json/0665.json (deflated 25%)
#   adding: content/mid_test_json/0880.json (deflated 25%)
#   adding: content/mid_test_json/0012.json (deflated 25%)
#   adding: content/mid_test_json/1118.json (deflated 25%)
#   adding: content/mid_test_json/0936.json (deflated 25%)
#   adding: content/mid_test_json/1208.json (deflated 24%)
#   adding: content/mid_test_json/0279.json (deflated 25%)
#   adding: content/mid_test_json/0134.json (deflated 24%)
#   adding: content/mid_test_json/0491.json (deflated 25%)
#   adding: content/mid_test_json/1075.json (deflated 25%)
#   adding: content/mid_test_json/0662.json (deflated 25%)
#   adding: content/mid_test_json/1365.json (deflated 25%)
#   adding: content/mid_test_json/0634.json (deflated 24%)
#   adding: content/mid_test_json/1104.json (deflated 24%)
#   adding: content/mid_test_json/0039.json (deflated 25%)
#   adding: content/mid_test_json/1094.json (deflated 25%)
#   adding: content/mid_test_json/1209.json (deflated 25%)
#   adding: content/mid_test_json/0823.json (deflated 25%)
#   adding: content/mid_test_json/1043.json (deflated 24%)
#   adding: content/mid_test_json/0737.json (deflated 25%)
#   adding: content/mid_test_json/0299.json (deflated 25%)
#   adding: content/mid_test_json/0318.json (deflated 25%)
#   adding: content/mid_test_json/1304.json (deflated 25%)
#   adding: content/mid_test_json/0367.json (deflated 25%)
#   adding: content/mid_test_json/1018.json (deflated 25%)
#   adding: content/mid_test_json/0482.json (deflated 25%)
#   adding: content/mid_test_json/1279.json (deflated 25%)
#   adding: content/mid_test_json/0985.json (deflated 25%)
#   adding: content/mid_test_json/0535.json (deflated 25%)
#   adding: content/mid_test_json/1390.json (deflated 24%)
#   adding: content/mid_test_json/0652.json (deflated 25%)
#   adding: content/mid_test_json/1392.json (deflated 24%)
#   adding: content/mid_test_json/1228.json (deflated 25%)
#   adding: content/mid_test_json/0966.json (deflated 24%)
#   adding: content/mid_test_json/0351.json (deflated 25%)
#   adding: content/mid_test_json/0453.json (deflated 25%)
#   adding: content/mid_test_json/0229.json (deflated 25%)
#   adding: content/mid_test_json/0000.json (deflated 25%)
#   adding: content/mid_test_json/0523.json (deflated 24%)
#   adding: content/mid_test_json/1034.json (deflated 25%)
#   adding: content/mid_test_json/1244.json (deflated 25%)
#   adding: content/mid_test_json/1344.json (deflated 24%)
#   adding: content/mid_test_json/0038.json (deflated 25%)
#   adding: content/mid_test_json/0470.json (deflated 25%)
#   adding: content/mid_test_json/0139.json (deflated 25%)
#   adding: content/mid_test_json/0232.json (deflated 25%)
#   adding: content/mid_test_json/0031.json (deflated 25%)
#   adding: content/mid_test_json/0528.json (deflated 25%)
#   adding: content/mid_test_json/0613.json (deflated 25%)
#   adding: content/mid_test_json/0664.json (deflated 25%)
#   adding: content/mid_test_json/0304.json (deflated 24%)
#   adding: content/mid_test_json/0717.json (deflated 25%)
#   adding: content/mid_test_json/1245.json (deflated 25%)
#   adding: content/mid_test_json/1287.json (deflated 25%)
#   adding: content/mid_test_json/1250.json (deflated 24%)
#   adding: content/mid_test_json/0184.json (deflated 25%)
#   adding: content/mid_test_json/0447.json (deflated 25%)
#   adding: content/mid_test_json/1114.json (deflated 24%)
#   adding: content/mid_test_json/1003.json (deflated 24%)
#   adding: content/mid_test_json/1184.json (deflated 24%)
#   adding: content/mid_test_json/0490.json (deflated 24%)
#   adding: content/mid_test_json/0356.json (deflated 24%)
#   adding: content/mid_test_json/0176.json (deflated 24%)
#   adding: content/mid_test_json/0330.json (deflated 25%)
#   adding: content/mid_test_json/1326.json (deflated 24%)
#   adding: content/mid_test_json/1246.json (deflated 25%)
#   adding: content/mid_test_json/0018.json (deflated 24%)
#   adding: content/mid_test_json/0030.json (deflated 25%)
#   adding: content/mid_test_json/0914.json (deflated 25%)
#   adding: content/mid_test_json/0961.json (deflated 25%)
#   adding: content/mid_test_json/0688.json (deflated 25%)
#   adding: content/mid_test_json/1031.json (deflated 25%)
#   adding: content/mid_test_json/0814.json (deflated 25%)
#   adding: content/mid_test_json/0086.json (deflated 25%)
#   adding: content/mid_test_json/0894.json (deflated 25%)
#   adding: content/mid_test_json/1243.json (deflated 25%)
#   adding: content/mid_test_json/0687.json (deflated 25%)
#   adding: content/mid_test_json/1139.json (deflated 25%)
#   adding: content/mid_test_json/0630.json (deflated 25%)
#   adding: content/mid_test_json/0701.json (deflated 25%)
#   adding: content/mid_test_json/0437.json (deflated 25%)
#   adding: content/mid_test_json/0551.json (deflated 25%)
#   adding: content/mid_test_json/0834.json (deflated 25%)
#   adding: content/mid_test_json/0615.json (deflated 24%)
#   adding: content/mid_test_json/0231.json (deflated 25%)
#   adding: content/mid_test_json/0004.json (deflated 24%)
#   adding: content/mid_test_json/0143.json (deflated 24%)
#   adding: content/mid_test_json/1081.json (deflated 25%)
#   adding: content/mid_test_json/0581.json (deflated 25%)
#   adding: content/mid_test_json/0389.json (deflated 25%)
#   adding: content/mid_test_json/0188.json (deflated 25%)
#   adding: content/mid_test_json/0674.json (deflated 25%)
#   adding: content/mid_test_json/0750.json (deflated 24%)
#   adding: content/mid_test_json/0675.json (deflated 24%)
#   adding: content/mid_test_json/0027.json (deflated 25%)
#   adding: content/mid_test_json/0711.json (deflated 24%)
#   adding: content/mid_test_json/0809.json (deflated 25%)
#   adding: content/mid_test_json/0478.json (deflated 24%)
#   adding: content/mid_test_json/1380.json (deflated 25%)
#   adding: content/mid_test_json/0873.json (deflated 25%)
#   adding: content/mid_test_json/0601.json (deflated 26%)
#   adding: content/mid_test_json/0715.json (deflated 24%)
#   adding: content/mid_test_json/0109.json (deflated 25%)
#   adding: content/mid_test_json/1092.json (deflated 25%)
#   adding: content/mid_test_json/0122.json (deflated 24%)
#   adding: content/mid_test_json/0181.json (deflated 25%)
#   adding: content/mid_test_json/0525.json (deflated 25%)
#   adding: content/mid_test_json/1080.json (deflated 25%)
#   adding: content/mid_test_json/0449.json (deflated 25%)
#   adding: content/mid_test_json/1331.json (deflated 25%)
#   adding: content/mid_test_json/1152.json (deflated 25%)
#   adding: content/mid_test_json/0693.json (deflated 25%)
#   adding: content/mid_test_json/1394.json (deflated 25%)
#   adding: content/mid_test_json/0514.json (deflated 25%)
#   adding: content/mid_test_json/0684.json (deflated 25%)
#   adding: content/mid_test_json/0309.json (deflated 25%)
#   adding: content/mid_test_json/0048.json (deflated 25%)
#   adding: content/mid_test_json/0815.json (deflated 25%)
#   adding: content/mid_test_json/0092.json (deflated 25%)
#   adding: content/mid_test_json/0399.json (deflated 25%)
#   adding: content/mid_test_json/0057.json (deflated 24%)
#   adding: content/mid_test_json/1128.json (deflated 25%)
#   adding: content/mid_test_json/0272.json (deflated 24%)
#   adding: content/mid_test_json/1185.json (deflated 25%)
#   adding: content/mid_test_json/1353.json (deflated 25%)
#   adding: content/mid_test_json/0545.json (deflated 26%)
#   adding: content/mid_test_json/0945.json (deflated 24%)
#   adding: content/mid_test_json/1194.json (deflated 25%)
#   adding: content/mid_test_json/0266.json (deflated 25%)
#   adding: content/mid_test_json/1178.json (deflated 25%)
#   adding: content/mid_test_json/0090.json (deflated 25%)
#   adding: content/mid_test_json/1172.json (deflated 25%)
#   adding: content/mid_test_json/0561.json (deflated 25%)
#   adding: content/mid_test_json/0282.json (deflated 24%)
#   adding: content/mid_test_json/1012.json (deflated 24%)
#   adding: content/mid_test_json/0337.json (deflated 25%)
#   adding: content/mid_test_json/0884.json (deflated 24%)
#   adding: content/mid_test_json/0504.json (deflated 24%)
#   adding: content/mid_test_json/0186.json (deflated 25%)
#   adding: content/mid_test_json/0574.json (deflated 24%)
#   adding: content/mid_test_json/0932.json (deflated 25%)
#   adding: content/mid_test_json/1263.json (deflated 25%)
#   adding: content/mid_test_json/0705.json (deflated 24%)
#   adding: content/mid_test_json/0026.json (deflated 25%)
#   adding: content/mid_test_json/0970.json (deflated 25%)
#   adding: content/mid_test_json/0281.json (deflated 25%)
#   adding: content/mid_test_json/0476.json (deflated 24%)
#   adding: content/mid_test_json/0096.json (deflated 24%)
#   adding: content/mid_test_json/0659.json (deflated 24%)
#   adding: content/mid_test_json/0103.json (deflated 25%)
#   adding: content/mid_test_json/1296.json (deflated 24%)
#   adding: content/mid_test_json/0762.json (deflated 24%)
#   adding: content/mid_test_json/1254.json (deflated 25%)
#   adding: content/mid_test_json/1320.json (deflated 24%)
#   adding: content/mid_test_json/0340.json (deflated 25%)
#   adding: content/mid_test_json/1328.json (deflated 25%)
#   adding: content/mid_test_json/0385.json (deflated 25%)
#   adding: content/mid_test_json/0288.json (deflated 24%)
#   adding: content/mid_test_json/0487.json (deflated 25%)
#   adding: content/mid_test_json/0452.json (deflated 25%)
#   adding: content/mid_test_json/1009.json (deflated 24%)
#   adding: content/mid_test_json/0443.json (deflated 24%)
#   adding: content/mid_test_json/0435.json (deflated 25%)
#   adding: content/mid_test_json/0498.json (deflated 24%)
#   adding: content/mid_test_json/1343.json (deflated 25%)
#   adding: content/mid_test_json/0124.json (deflated 24%)
#   adding: content/mid_test_json/0448.json (deflated 25%)
#   adding: content/mid_test_json/0597.json (deflated 24%)
#   adding: content/mid_test_json/0536.json (deflated 25%)
#   adding: content/mid_test_json/1073.json (deflated 25%)
#   adding: content/mid_test_json/1211.json (deflated 24%)
#   adding: content/mid_test_json/0381.json (deflated 25%)
#   adding: content/mid_test_json/0393.json (deflated 24%)
#   adding: content/mid_test_json/0774.json (deflated 25%)
#   adding: content/mid_test_json/1212.json (deflated 25%)
#   adding: content/mid_test_json/0357.json (deflated 25%)
#   adding: content/mid_test_json/0807.json (deflated 25%)
#   adding: content/mid_test_json/0969.json (deflated 24%)
#   adding: content/mid_test_json/0532.json (deflated 25%)
#   adding: content/mid_test_json/1082.json (deflated 24%)
#   adding: content/mid_test_json/0746.json (deflated 24%)
#   adding: content/mid_test_json/0871.json (deflated 25%)
#   adding: content/mid_test_json/0620.json (deflated 24%)
#   adding: content/mid_test_json/1324.json (deflated 25%)
#   adding: content/mid_test_json/0252.json (deflated 24%)
#   adding: content/mid_test_json/0146.json (deflated 25%)
#   adding: content/mid_test_json/0598.json (deflated 24%)
#   adding: content/mid_test_json/0431.json (deflated 25%)
#   adding: content/mid_test_json/0497.json (deflated 24%)
#   adding: content/mid_test_json/0014.json (deflated 25%)
#   adding: content/mid_test_json/0903.json (deflated 25%)
#   adding: content/mid_test_json/1402.json (deflated 24%)
#   adding: content/mid_test_json/0553.json (deflated 24%)
#   adding: content/mid_test_json/0268.json (deflated 24%)
#   adding: content/mid_test_json/1367.json (deflated 25%)
#   adding: content/mid_test_json/1347.json (deflated 25%)
#   adding: content/mid_test_json/0079.json (deflated 25%)
#   adding: content/mid_test_json/1108.json (deflated 25%)
#   adding: content/mid_test_json/0242.json (deflated 25%)
#   adding: content/mid_test_json/0320.json (deflated 25%)
#   adding: content/mid_test_json/0837.json (deflated 25%)
#   adding: content/mid_test_json/0816.json (deflated 25%)
#   adding: content/mid_test_json/1020.json (deflated 24%)
#   adding: content/mid_test_json/1122.json (deflated 24%)
#   adding: content/mid_test_json/0081.json (deflated 25%)
#   adding: content/mid_test_json/0689.json (deflated 25%)
#   adding: content/mid_test_json/1101.json (deflated 25%)
#   adding: content/mid_test_json/0374.json (deflated 25%)
#   adding: content/mid_test_json/0726.json (deflated 25%)
#   adding: content/mid_test_json/0328.json (deflated 25%)
#   adding: content/mid_test_json/1165.json (deflated 25%)
#   adding: content/mid_test_json/0869.json (deflated 25%)
#   adding: content/mid_test_json/0656.json (deflated 24%)
#   adding: content/mid_test_json/0858.json (deflated 25%)
#   adding: content/mid_test_json/1133.json (deflated 25%)
#   adding: content/mid_test_json/0805.json (deflated 25%)
#   adding: content/mid_test_json/0900.json (deflated 25%)
#   adding: content/mid_test_json/0860.json (deflated 24%)
#   adding: content/mid_test_json/0569.json (deflated 24%)
#   adding: content/mid_test_json/0326.json (deflated 25%)
#   adding: content/mid_test_json/1375.json (deflated 24%)
#   adding: content/mid_test_json/1021.json (deflated 25%)
#   adding: content/mid_test_json/1225.json (deflated 25%)
#   adding: content/mid_test_json/0347.json (deflated 25%)
#   adding: content/mid_test_json/1261.json (deflated 25%)
#   adding: content/mid_test_json/0162.json (deflated 24%)
#   adding: content/mid_test_json/0580.json (deflated 25%)
#   adding: content/mid_test_json/1001.json (deflated 25%)
#   adding: content/mid_test_json/0707.json (deflated 26%)
#   adding: content/mid_test_json/0817.json (deflated 25%)
#   adding: content/mid_test_json/1097.json (deflated 25%)
#   adding: content/mid_test_json/0939.json (deflated 25%)
#   adding: content/mid_test_json/0365.json (deflated 24%)
#   adding: content/mid_test_json/0305.json (deflated 25%)
#   adding: content/mid_test_json/1216.json (deflated 25%)
#   adding: content/mid_test_json/0587.json (deflated 25%)
#   adding: content/mid_test_json/0851.json (deflated 24%)
#   adding: content/mid_test_json/0585.json (deflated 25%)
#   adding: content/mid_test_json/0060.json (deflated 25%)
#   adding: content/mid_test_json/0546.json (deflated 25%)
#   adding: content/mid_test_json/0968.json (deflated 25%)
#   adding: content/mid_test_json/1321.json (deflated 24%)
#   adding: content/mid_test_json/1260.json (deflated 24%)
#   adding: content/mid_test_json/1413.json (deflated 24%)
#   adding: content/mid_test_json/1415.json (deflated 25%)
#   adding: content/mid_test_json/1016.json (deflated 24%)
#   adding: content/mid_test_json/0091.json (deflated 25%)
#   adding: content/mid_test_json/0933.json (deflated 25%)
#   adding: content/mid_test_json/0624.json (deflated 25%)
#   adding: content/mid_test_json/1063.json (deflated 25%)
#   adding: content/mid_test_json/0225.json (deflated 25%)
#   adding: content/mid_test_json/0781.json (deflated 25%)
#   adding: content/mid_test_json/0792.json (deflated 24%)
#   adding: content/mid_test_json/0882.json (deflated 25%)
#   adding: content/mid_test_json/0678.json (deflated 25%)
#   adding: content/mid_test_json/1300.json (deflated 25%)
#   adding: content/mid_test_json/0179.json (deflated 25%)
#   adding: content/mid_test_json/0474.json (deflated 24%)
#   adding: content/mid_test_json/1323.json (deflated 24%)
#   adding: content/mid_test_json/0432.json (deflated 25%)
#   adding: content/mid_test_json/0335.json (deflated 25%)
#   adding: content/mid_test_json/0962.json (deflated 25%)
# ...
#   adding: content/mid_test_json/0874.json (deflated 25%)
#   adding: content/mid_test_json/0164.json (deflated 25%)
#   adding: content/mid_test_json/0768.json (deflated 25%)
#   adding: content/mid_test_json/0433.json (deflated 25%)
#   adding: content/mid_test_json/0360.json (deflated 24%)
#   adding: content/mid_test_json/0423.json (deflated 25%)
#   adding: content/mid_test_json/1409.json (deflated 25%)
#   adding: content/mid_test_json/1039.json (deflated 25%)
#   adding: content/mid_test_json/0928.json (deflated 24%)
#   adding: content/mid_test_json/0794.json (deflated 25%)
#   adding: content/mid_test_json/0368.json (deflated 25%)
#   adding: content/mid_test_json/0940.json (deflated 24%)
#   adding: content/mid_test_json/1135.json (deflated 24%)
#   adding: content/mid_test_json/1231.json (deflated 25%)
#   adding: content/mid_test_json/1072.json (deflated 25%)
#   adding: content/mid_test_json/0154.json (deflated 25%)
#   adding: content/mid_test_json/0419.json (deflated 25%)
#   adding: content/mid_test_json/0877.json (deflated 25%)
#   adding: content/mid_test_json/0313.json (deflated 25%)
#   adding: content/mid_test_json/0942.json (deflated 24%)
#   adding: content/mid_test_json/0844.json (deflated 24%)
#   adding: content/mid_test_json/0019.json (deflated 25%)
#   adding: content/mid_test_json/1205.json (deflated 24%)
#   adding: content/mid_test_json/0277.json (deflated 25%)
#   adding: content/mid_test_json/1398.json (deflated 25%)
#   adding: content/mid_test_json/0310.json (deflated 25%)
#   adding: content/mid_test_json/0512.json (deflated 24%)
#   adding: content/mid_test_json/0611.json (deflated 24%)
#   adding: content/mid_test_json/0191.json (deflated 25%)
#   adding: content/mid_test_json/0627.json (deflated 25%)
#   adding: content/mid_test_json/0990.json (deflated 24%)
#   adding: content/mid_test_json/1348.json (deflated 24%)
#   adding: content/mid_test_json/0076.json (deflated 25%)
#   adding: content/mid_test_json/1124.json (deflated 24%)
#   adding: content/mid_test_json/1388.json (deflated 25%)
#   adding: content/mid_test_json/0922.json (deflated 24%)
#   adding: content/mid_test_json/0848.json (deflated 25%)
#   adding: content/mid_test_json/0428.json (deflated 25%)
#   adding: content/mid_test_json/0338.json (deflated 25%)
#   adding: content/mid_test_json/0121.json (deflated 25%)
#   adding: content/mid_test_json/1285.json (deflated 25%)
#   adding: content/mid_test_json/1171.json (deflated 24%)
#   adding: content/mid_test_json/1166.json (deflated 25%)
#   adding: content/mid_test_json/0779.json (deflated 25%)
#   adding: content/mid_test_json/1276.json (deflated 24%)
#   adding: content/mid_test_json/0246.json (deflated 25%)
#   adding: content/mid_test_json/1044.json (deflated 25%)
#   adding: content/mid_test_json/0061.json (deflated 24%)
#   adding: content/mid_test_json/0669.json (deflated 25%)
#   adding: content/mid_test_json/1255.json (deflated 25%)
#   adding: content/mid_test_json/0273.json (deflated 25%)
#   adding: content/mid_test_json/0046.json (deflated 25%)
#   adding: content/mid_test_json/0702.json (deflated 24%)
#   adding: content/mid_test_json/0812.json (deflated 25%)
#   adding: content/mid_test_json/0733.json (deflated 25%)
#   adding: content/mid_test_json/0889.json (deflated 25%)
#   adding: content/mid_test_json/0406.json (deflated 25%)
#   adding: content/mid_test_json/0163.json (deflated 25%)
#   adding: content/mid_test_json/1274.json (deflated 24%)
#   adding: content/mid_test_json/0325.json (deflated 25%)
#   adding: content/mid_test_json/0021.json (deflated 25%)
#   adding: content/mid_test_json/0190.json (deflated 25%)
#   adding: content/mid_test_json/0170.json (deflated 25%)
#   adding: content/mid_test_json/0319.json (deflated 26%)
#   adding: content/mid_test_json/0960.json (deflated 25%)
#   adding: content/mid_test_json/0681.json (deflated 25%)
#   adding: content/mid_test_json/1266.json (deflated 24%)
#   adding: content/mid_test_json/0594.json (deflated 25%)
#   adding: content/mid_test_json/0938.json (deflated 25%)
#   adding: content/mid_test_json/1363.json (deflated 24%)
#   adding: content/mid_test_json/1298.json (deflated 25%)
#   adding: content/mid_test_json/0180.json (deflated 24%)
#   adding: content/mid_test_json/1294.json (deflated 24%)
#   adding: content/mid_test_json/0413.json (deflated 25%)
#   adding: content/mid_test_json/1397.json (deflated 24%)
#   adding: content/mid_test_json/0506.json (deflated 25%)
#   adding: content/mid_test_json/1151.json (deflated 25%)
#   adding: content/mid_test_json/0735.json (deflated 25%)
#   adding: content/mid_test_json/0187.json (deflated 24%)
#   adding: content/mid_test_json/0245.json (deflated 24%)
#   adding: content/mid_test_json/1137.json (deflated 24%)
#   adding: content/mid_test_json/0847.json (deflated 25%)
#   adding: content/mid_test_json/0481.json (deflated 24%)
#   adding: content/mid_test_json/0635.json (deflated 25%)
#   adding: content/mid_test_json/1111.json (deflated 24%)
#   adding: content/mid_test_json/1421.json (deflated 25%)
#   adding: content/mid_test_json/0700.json (deflated 24%)
#   adding: content/mid_test_json/0756.json (deflated 25%)
#   adding: content/mid_test_json/0738.json (deflated 25%)
#   adding: content/mid_test_json/0992.json (deflated 24%)
#   adding: content/mid_test_json/0628.json (deflated 25%)
#   adding: content/mid_test_json/1361.json (deflated 25%)
#   adding: content/mid_test_json/1069.json (deflated 25%)
#   adding: content/mid_test_json/0352.json (deflated 25%)
#   adding: content/mid_test_json/0667.json (deflated 24%)
#   adding: content/mid_test_json/0531.json (deflated 24%)
#   adding: content/mid_test_json/0820.json (deflated 25%)
#   adding: content/mid_test_json/1235.json (deflated 24%)
#   adding: content/mid_test_json/0339.json (deflated 25%)
#   adding: content/mid_test_json/0510.json (deflated 24%)
#   adding: content/mid_test_json/0921.json (deflated 24%)
#   adding: content/mid_test_json/0964.json (deflated 24%)
#   adding: content/mid_test_json/0094.json (deflated 25%)
#   adding: content/mid_test_json/1192.json (deflated 25%)
#   adding: content/mid_test_json/0020.json (deflated 25%)
#   adding: content/mid_test_json/1041.json (deflated 24%)
#   adding: content/mid_test_json/0998.json (deflated 24%)
#   adding: content/mid_test_json/0040.json (deflated 25%)
#   adding: content/mid_test_json/0987.json (deflated 24%)
#   adding: content/mid_test_json/0663.json (deflated 25%)
#   adding: content/mid_test_json/0227.json (deflated 25%)
#   adding: content/mid_test_json/0396.json (deflated 25%)
#   adding: content/mid_test_json/1269.json (deflated 25%)
#   adding: content/mid_test_json/0128.json (deflated 25%)
#   adding: content/mid_test_json/0575.json (deflated 25%)
#   adding: content/mid_test_json/0074.json (deflated 24%)
#   adding: content/mid_test_json/0071.json (deflated 24%)
#   adding: content/mid_test_json/0957.json (deflated 24%)
#   adding: content/mid_test_json/0954.json (deflated 24%)
#   adding: content/mid_test_json/1195.json (deflated 25%)
#   adding: content/mid_test_json/0002.json (deflated 25%)
#   adding: content/mid_test_json/0345.json (deflated 26%)
#   adding: content/mid_test_json/0250.json (deflated 25%)
#   adding: content/mid_test_json/1204.json (deflated 25%)
#   adding: content/mid_test_json/0788.json (deflated 25%)
#   adding: content/mid_test_json/1407.json (deflated 25%)
#   adding: content/mid_test_json/0416.json (deflated 24%)
#   adding: content/mid_test_json/0130.json (deflated 25%)
#   adding: content/mid_test_json/0085.json (deflated 25%)
#   adding: content/mid_test_json/1077.json (deflated 25%)
#   adding: content/mid_test_json/0777.json (deflated 25%)
#   adding: content/mid_test_json/1342.json (deflated 24%)
#   adding: content/mid_test_json/1362.json (deflated 25%)
#   adding: content/mid_test_json/0316.json (deflated 25%)
#   adding: content/mid_test_json/0120.json (deflated 25%)
#   adding: content/mid_test_json/0778.json (deflated 25%)
#   adding: content/mid_test_json/0579.json (deflated 25%)
#   adding: content/mid_test_json/0495.json (deflated 25%)
#   adding: content/mid_test_json/0468.json (deflated 25%)
#   adding: content/mid_test_json/0690.json (deflated 25%)
#   adding: content/mid_test_json/1233.json (deflated 24%)
#   adding: content/mid_test_json/0626.json (deflated 25%)
#   adding: content/mid_test_json/1197.json (deflated 25%)
#   adding: content/mid_test_json/1193.json (deflated 24%)
#   adding: content/mid_test_json/0488.json (deflated 25%)
#   adding: content/mid_test_json/0462.json (deflated 25%)
#   adding: content/mid_test_json/1014.json (deflated 24%)
#   adding: content/mid_test_json/1312.json (deflated 24%)
#   adding: content/mid_test_json/1222.json (deflated 25%)
#   adding: content/mid_test_json/0332.json (deflated 26%)
#   adding: content/mid_test_json/0141.json (deflated 24%)
#   adding: content/mid_test_json/0212.json (deflated 25%)
#   adding: content/mid_test_json/0099.json (deflated 25%)
#   adding: content/mid_test_json/1400.json (deflated 25%)
#   adding: content/mid_test_json/0919.json (deflated 24%)
#   adding: content/mid_test_json/0362.json (deflated 25%)
#   adding: content/mid_test_json/0605.json (deflated 25%)
#   adding: content/mid_test_json/0285.json (deflated 25%)
#   adding: content/mid_test_json/1206.json (deflated 25%)
#   adding: content/mid_test_json/0818.json (deflated 25%)
#   adding: content/mid_test_json/1221.json (deflated 25%)
#   adding: content/mid_test_json/1218.json (deflated 24%)
#   adding: content/mid_test_json/0720.json (deflated 25%)
#   adding: content/mid_test_json/1303.json (deflated 25%)
#   adding: content/mid_test_json/0971.json (deflated 25%)
#   adding: content/mid_test_json/0469.json (deflated 25%)
#   adding: content/mid_test_json/0221.json (deflated 25%)
#   adding: content/mid_test_json/0849.json (deflated 25%)
#   adding: content/mid_test_json/0973.json (deflated 25%)
#   adding: content/mid_test_json/0261.json (deflated 25%)
#   adding: content/mid_test_json/0704.json (deflated 25%)
#   adding: content/mid_test_json/0195.json (deflated 25%)
#   adding: content/mid_test_json/0471.json (deflated 24%)
#   adding: content/mid_test_json/0632.json (deflated 24%)
#   adding: content/mid_test_json/1093.json (deflated 25%)
#   adding: content/mid_test_json/0077.json (deflated 25%)
#   adding: content/mid_test_json/1036.json (deflated 24%)
#   adding: content/mid_test_json/0950.json (deflated 25%)
#   adding: content/mid_test_json/0893.json (deflated 25%)
#   adding: content/mid_test_json/0748.json (deflated 25%)
#   adding: content/mid_test_json/1339.json (deflated 24%)
#   adding: content/mid_test_json/1105.json (deflated 25%)
#   adding: content/mid_test_json/0439.json (deflated 25%)
#   adding: content/mid_test_json/0424.json (deflated 25%)
#   adding: content/mid_test_json/1047.json (deflated 25%)
#   adding: content/mid_test_json/0003.json (deflated 25%)
#   adding: content/mid_test_json/0616.json (deflated 24%)
#   adding: content/mid_test_json/0472.json (deflated 24%)
#   adding: content/mid_test_json/1100.json (deflated 25%)
#   adding: content/mid_test_json/1179.json (deflated 25%)
#   adding: content/mid_test_json/0683.json (deflated 25%)
#   adding: content/mid_test_json/0069.json (deflated 25%)
#   adding: content/mid_test_json/0240.json (deflated 25%)
#   adding: content/mid_test_json/0671.json (deflated 24%)
#   adding: content/mid_test_json/0334.json (deflated 25%)
#   adding: content/mid_test_json/1322.json (deflated 24%)
#   adding: content/mid_test_json/0584.json (deflated 25%)
#   adding: content/mid_test_json/1393.json (deflated 24%)
#   adding: content/mid_test_json/1134.json (deflated 25%)
#   adding: content/mid_test_json/0765.json (deflated 25%)
#   adding: content/mid_test_json/0771.json (deflated 25%)
#   adding: content/mid_test_json/1338.json (deflated 24%)
#   adding: content/mid_test_json/0113.json (deflated 24%)
#   adding: content/mid_test_json/0967.json (deflated 25%)
#   adding: content/mid_test_json/0397.json (deflated 26%)
#   adding: content/mid_test_json/0516.json (deflated 25%)
#   adding: content/mid_test_json/0840.json (deflated 24%)
#   adding: content/mid_test_json/0479.json (deflated 24%)
#   adding: content/mid_test_json/0446.json (deflated 24%)
#   adding: content/mid_test_json/0390.json (deflated 25%)
#   adding: content/mid_test_json/0107.json (deflated 25%)
#   adding: content/mid_test_json/0486.json (deflated 25%)
#   adding: content/mid_test_json/0822.json (deflated 25%)
#   adding: content/mid_test_json/0059.json (deflated 25%)
#   adding: content/mid_test_json/0752.json (deflated 25%)
#   adding: content/mid_test_json/1127.json (deflated 24%)
#   adding: content/mid_test_json/0582.json (deflated 25%)
#   adding: content/mid_test_json/0731.json (deflated 24%)
#   adding: content/mid_test_json/0114.json (deflated 25%)
#   adding: content/mid_test_json/1079.json (deflated 24%)
#   adding: content/mid_test_json/0493.json (deflated 25%)
#   adding: content/mid_test_json/0784.json (deflated 24%)
#   adding: content/mid_test_json/1070.json (deflated 24%)
#   adding: content/mid_test_json/1119.json (deflated 24%)
#   adding: content/mid_test_json/0829.json (deflated 25%)
#   adding: content/mid_test_json/0866.json (deflated 24%)
#   adding: content/mid_test_json/0132.json (deflated 25%)
#   adding: content/mid_test_json/0975.json (deflated 25%)
#   adding: content/mid_test_json/1396.json (deflated 24%)
#   adding: content/mid_test_json/1056.json (deflated 25%)
#   adding: content/mid_test_json/0192.json (deflated 25%)
#   adding: content/mid_test_json/0824.json (deflated 26%)
#   adding: content/mid_test_json/0025.json (deflated 25%)
#   adding: content/mid_test_json/0606.json (deflated 24%)
#   adding: content/mid_test_json/0842.json (deflated 25%)
#   adding: content/mid_test_json/0308.json (deflated 24%)
#   adding: content/mid_test_json/0533.json (deflated 24%)
#   adding: content/mid_test_json/0503.json (deflated 25%)
#   adding: content/mid_test_json/0280.json (deflated 25%)
#   adding: content/mid_test_json/0175.json (deflated 24%)
#   adding: content/mid_test_json/0550.json (deflated 24%)
#   adding: content/mid_test_json/0567.json (deflated 25%)
#   adding: content/mid_test_json/1311.json (deflated 24%)
#   adding: content/mid_test_json/0438.json (deflated 25%)
#   adding: content/mid_test_json/1200.json (deflated 25%)
#   adding: content/mid_test_json/0007.json (deflated 25%)
#   adding: content/mid_test_json/0595.json (deflated 24%)
#   adding: content/mid_test_json/0608.json (deflated 25%)
#   adding: content/mid_test_json/0799.json (deflated 25%)
#   adding: content/mid_test_json/0872.json (deflated 25%)
#   adding: content/mid_test_json/0301.json (deflated 25%)
#   adding: content/mid_test_json/1176.json (deflated 25%)
#   adding: content/mid_test_json/0691.json (deflated 25%)
#   adding: content/mid_test_json/1389.json (deflated 25%)
#   adding: content/mid_test_json/0573.json (deflated 25%)
#   adding: content/mid_test_json/1045.json (deflated 24%)
#   adding: content/mid_test_json/0228.json (deflated 25%)
#   adding: content/mid_test_json/0706.json (deflated 25%)
#   adding: content/mid_test_json/0797.json (deflated 25%)
#   adding: content/mid_test_json/0591.json (deflated 24%)
#   adding: content/mid_test_json/0638.json (deflated 25%)
#   adding: content/mid_test_json/0262.json (deflated 25%)
#   adding: content/mid_test_json/0033.json (deflated 25%)
#   adding: content/mid_test_json/1370.json (deflated 25%)
#   adding: content/mid_test_json/1306.json (deflated 24%)
#   adding: content/mid_test_json/1283.json (deflated 25%)
#   adding: content/mid_test_json/1317.json (deflated 24%)
#   adding: content/mid_test_json/0757.json (deflated 25%)
#   adding: content/mid_test_json/0055.json (deflated 25%)
#   adding: content/mid_test_json/1161.json (deflated 24%)
#   adding: content/mid_test_json/0248.json (deflated 25%)
#   adding: content/mid_test_json/1272.json (deflated 24%)
#   adding: content/mid_test_json/1364.json (deflated 24%)
#   adding: content/mid_test_json/0189.json (deflated 25%)
#   adding: content/mid_test_json/1088.json (deflated 25%)
#   adding: content/mid_test_json/0833.json (deflated 25%)
#   adding: content/mid_test_json/1224.json (deflated 25%)
#   adding: content/mid_test_json/0764.json (deflated 24%)
#   adding: content/mid_test_json/1280.json (deflated 25%)
#   adding: content/mid_test_json/0155.json (deflated 25%)

# %%
# !mkdir /content/change_json

# %%
# !unzip /content/ezgif_150_5-JSON.zip -d /content/change_json
# Out:
# Archive:  /content/ezgif_150_5-JSON.zip
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-034.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-044.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-066.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-118.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-145.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-020.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-001.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-079.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-062.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-138.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-122.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-043.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-142.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-009.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-093.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-134.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-024.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-018.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-100.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-013.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-028.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-107.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-057.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-047.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-004.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-113.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-129.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-094.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-053.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-006.json
#   inflating: /content/change_json/ezgif_150_5/ezgif-frame-103.json

# %%
# import os
# import json

# %%
# Directory containing the JSON files
# dir_path = '/content/change_json/ezgif_150_5'

# # Loop through each file in the directory
# for filename in os.listdir(dir_path):
#     if filename.endswith('.json'):
#         # Open the JSON file and load the data
#         with open(os.path.join(dir_path, filename), 'r') as f:
#             data = json.load(f)

#         # Modify the labels based on their length
#         for shape in data['shapes']:
#             if shape['label'] == 1 or shape['label'] == 2 or shape['label'] == 3 or shape['label'] == 4:
#                 shape['label'] = 'Head'
#             elif shape['label'] == 11 or shape['label'] == 22 or shape['label'] == 33 or shape['label'] == 44:
#                 shape['label'] = 'Body'
        
#         # Write the modified JSON back to the file
#         with open(os.path.join(dir_path, filename), 'w') as f:
#             json.dump(data, f)
